# %% [markdown]
# # Functions in python.
# - block of statement that perform a specific task (group).

# %%
# function definition.
# def func_name(Param1,Param2...)#same work.

def calc_sum(a,b):#parameterm\
    return (a + b)

    sum = calc_sum ( 1,2)#function call (1,2)->argument
    print(sum)

print(calc_sum(2,3))
print(calc_sum(178,99))
# Out:
# 5
# 277

# %%
#average of 3 numbers.

def calc_avg (a,b,c):
    sum = a + b + c
    avg = sum/3
    print(avg)
    return(avg)
 
calc_avg(98,97,96)
# Out:
# 97.0
# 97.0

# %% [markdown]
# # types
# - 01_built in function
# - print(),len(),type(),range().
# - 02_user defined functions.

# %% [markdown]
# # default Parameters.
# -  Assigning a default value to parameter which is used when no argument is passed.

# %%
def cal_prod(a, b=2):#default parameter
    print(a*b)
   
cal_prod(1)
# Out:
# 2

# %% [markdown]
# # Lets Practice.

# %%
# write a function print the length of a list.

cities = ["delhi","pune","mumbai","banglore"]
cricketers =["rohit","virat","dhoni","sachin","rahul"]

def print_len(list):
    print(len(list))

print_len(cities)
print_len(cricketers)
# Out:
# 4
# 5

# %%
#write a function to print the elements of a list in a single line.

cities = ["delhi","pune","mumbai","banglore"]
cricketers =["rohit","virat","dhoni","sachin","rahul"]

def print_list(list):
    for item in list:
        print(item, end=" ")

print_list(cities)
print_list(cricketers)
print()
# Out:
# delhi pune mumbai banglore rohit virat dhoni sachin rahul

# %%
#find the factorial of n : (n is a parameter)

# n = 5
# fact = 1
# for i in range(1,n+1):
#     fact *= i
#     print(fact)

def cal_fact(n):
    fact = 1
    for i in range(1,n+1):
        fact *=i
        print(fact)
(cal_fact(7))
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040

# %%
# write a function to convert usd to inr.
#1 usd = 83

def converter(USD_val):
    inr_val= USD_val * 83
    print(USD_val, "USD =", inr_val,"INR")

(converter(8))
(converter(100))
# Out:
# 8 USD = 664 INR
# 100 USD = 8300 INR

# %% [markdown]
# # recursion :-
# - when a function calls itself repeadtedly.

# %%
#recursive function.

def show(n):
    if(n == 0):
        return
    print(n)
    show(n-1)

show(6)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
# returns n !
def fact(n):
    if(n == 0 or n == 1):
        return 1
    else :
        return n * fact (n-1)
    
print(fact(8))
# Out:
# 40320

# %%
def fact(n):
    if(n == 1 or n == 0):
        return 1
    else: 
        return fact (n-1)*n
    
print(fact(9))
# Out:
# 362880

# %% [markdown]
# # Lets Practice.

# %%
#write a recursive function to calculate the sum of first n Natural numbers.

def calc_sum(n):
    if(n == 0):
        return 0
    return calc_sum(n - 1)+ n
sum = calc_sum(8)
print(sum)
# Out:
# 36

# %%
# write a recursive function to print all elements in list.
# Hint : use list and index as parameters.

def print_list(list,idx = 0):
    if(idx == len(list)):
        return
    print(list[idx])
    print_list(list,idx +1)

fruits = ["mango","litchi","apple","banana"]
print_list(fruits)
# Out:
# mango
# litchi
# apple
# banana
